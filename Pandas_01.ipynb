# %% [markdown]
# <a href="https://colab.research.google.com/github/labib1910024/Python_basic/blob/main/Pandas_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/Iris.csv')

# %%
data.shape
# Out:
# (150, 6)

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data = data.drop(['Id'],axis=1)

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
data = pd.DataFrame()
data['Age']=[13,12,14,15]
data['Name']=['Labib','Ashik','Galib','Saikat']

# %%
data
# Out:
#    Age    Name
# 0   13   Labib
# 1   12   Ashik
# 2   14   Galib
# 3   15  Saikat

# %%
data = data.drop_duplicates()

# %%
data = data.reset_index()

# %%
data = data.drop(['index'],axis=1)

# %%
data = data.drop([1],axis=0)

# %%
data.iloc[3,[1]]
# Out:
# Name    Saikat
# Name: 3, dtype: object

# %%
data.loc[3]
# Out:
# Age         15
# Name    Saikat
# Name: 3, dtype: object

# %%
data.iloc[[2,3],[0,1]]
# Out:
#    Age    Name
# 2   14   Galib
# 3   15  Saikat

# %%
data1 = pd.DataFrame()
data1['age']=[13,12,14,15]
data1['name']=['Labib','Ashik','Galib','Saikat']
data1
# Out:
#    age    name
# 0   13   Labib
# 1   12   Ashik
# 2   14   Galib
# 3   15  Saikat
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data1['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# data1.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
data2 = pd.DataFrame()
data2['age']=[13,12,14,15]
data2['weight']=[70,53,75,78]
data2
# Out:
#    age  weight
# 0   13      70
# 1   12      53
# 2   14      75
# 3   15      78

# %%
data_combined = pd.merge(data1, data2, on='age')
print(data_combined)
# Out:
#    age    name  weight
# 0   13   Labib      70
# 1   12   Ashik      53
# 2   14   Galib      75
# 3   15  Saikat      78

# %%
data_combined = pd.concat([data1, data2], axis=1)
print(data_combined)
# Out:
#    age    name  age  weight
# 0   13   Labib   13      70
# 1   12   Ashik   12      53
# 2   14   Galib   14      75
# 3   15  Saikat   15      78

# %%
import pandas as pd
data =[[420,50],[380,40],[390,45]]
df = pd .DataFrame(data,index=["day1","day2","day3"],columns=["cal","dur"])
df
# Out:
#       cal  dur
# day1  420   50
# day2  380   40
# day3  390   45

# %%
Classroom ={
             'A':{'Roll': 24,'Sub':{'Phy':80, 'Math':85, 'Chem': 90}},
             'B':{'Roll': 25,'Sub':{'Phy':90, 'Math':95, 'Chem': 99}},
             'C':{'Roll': 26,'Sub':{'Phy':90, 'Math':87, 'Chem': 100}},
             'D':{'Roll': 27,'Sub':{'Phy':89, 'Math':98, 'Chem': 92}},
             'E':{'Roll': 28,'Sub':{'Phy':97, 'Math':93, 'Chem': 70}}
            }

# %%
import pandas as pd
data = {
    "calories":[420,380,300],
    "duration":[50,40,45]
}
df = pd .DataFrame(data,index=["day1","day2","day3"])
display(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       300        45

# %%
# Dictionary for a person
person = {
    'name': 'Alice',
    'age': 28,
    'city': 'Los Angeles'
}

# Dictionary for a book
book = {
    'title': '1984',
    'author': 'George Orwell',
    'year_published': 1949
}

print("Person Dictionary:", person)
print("Book Dictionary:", book)
# Out:
# Person Dictionary: {'name': 'Alice', 'age': 28, 'city': 'Los Angeles'}
# Book Dictionary: {'title': '1984', 'author': 'George Orwell', 'year_published': 1949}

# %%
# Dictionary for employees
import pandas as pd
employees = {
    'E001': {'name': 'John Doe', 'age': 30, 'department': 'HR'},
    'E002': {'name': 'Jane Smith', 'age': 25, 'department': 'Finance'},
    'E003': {'name': 'Emily Davis', 'age': 35, 'department': 'IT'}
}
df1 = pd.DataFrame(employees)
# Dictionary for departments
departments = {
    'HR': {'head': 'Alice Brown', 'location': 'Building A'},
    'Finance': {'head': 'Robert Black', 'location': 'Building B'},
    'IT': {'head': 'Carol White', 'location': 'Building C'}
}
df2 = pd .DataFrame(departments)
print("Employees Dictionary:", employees)
print("Departments Dictionary:", departments)
# Out:
# Employees Dictionary: {'E001': {'name': 'John Doe', 'age': 30, 'department': 'HR'}, 'E002': {'name': 'Jane Smith', 'age': 25, 'department': 'Finance'}, 'E003': {'name': 'Emily Davis', 'age': 35, 'department': 'IT'}}
# Departments Dictionary: {'HR': {'head': 'Alice Brown', 'location': 'Building A'}, 'Finance': {'head': 'Robert Black', 'location': 'Building B'}, 'IT': {'head': 'Carol White', 'location': 'Building C'}}

# %%
df1
# Out:
#                 E001        E002         E003
# name        John Doe  Jane Smith  Emily Davis
# age               30          25           35
# department        HR     Finance           IT

# %%
df2
# Out:
#                    HR       Finance           IT
# head      Alice Brown  Robert Black  Carol White
# location   Building A    Building B   Building C

# %%
import pandas as pd

# Define a dictionary containing employee data
data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],}

# Define a dictionary containing employee data
data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']}


df = pd.DataFrame(data1)
df1 = pd.DataFrame(data2)

# %%
df
# Out:
#   key    Name  Age
# 0  K0     Jai   27
# 1  K1  Princi   24
# 2  K2  Gaurav   22
# 3  K3    Anuj   32

# %%
df1
# Out:
#                 E001        E002         E003
# name        John Doe  Jane Smith  Emily Davis
# age               30          25           35
# department        HR     Finance           IT

# %%
res = pd.merge(df, df1, on='key')
res
# Out:
#   key    Name  Age    Address Qualification
# 0  K0     Jai   27     Nagpur         Btech
# 1  K1  Princi   24     Kanpur           B.A
# 2  K2  Gaurav   22  Allahabad          Bcom
# 3  K3    Anuj   32    Kannuaj        B.hons

# %%
import pandas as pd

# Define a dictionary containing employee data
data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K1', 'K0', 'K1'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],}

# Define a dictionary containing employee data
data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K0', 'K0', 'K0'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']}


df = pd.DataFrame(data1)
df1 = pd.DataFrame(data2)

# %%
res1 = pd.merge(df, df1, on=['key', 'key1'])

res1
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K2   K0  Gaurav   22  Allahabad          Bcom

# %%
import pandas as pd

# Define a dictionary containing employee data
data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K1', 'K0', 'K1'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],}

# Define a dictionary containing employee data
data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K0', 'K0', 'K0'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']}


df = pd.DataFrame(data1)
df1 = pd.DataFrame(data2)

# %%
res = pd.merge(df, df1, how='left', on=['key', 'key1'])

res
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K1   K1  Princi   24        NaN           NaN
# 2  K2   K0  Gaurav   22  Allahabad          Bcom
# 3  K3   K1    Anuj   32        NaN           NaN

# %%
res = pd.merge(df, df1, how='right', on=['key', 'key1'])

res
# Out:
#   key key1    Name   Age    Address Qualification
# 0  K0   K0     Jai  27.0     Nagpur         Btech
# 1  K1   K0     NaN   NaN     Kanpur           B.A
# 2  K2   K0  Gaurav  22.0  Allahabad          Bcom
# 3  K3   K0     NaN   NaN    Kannuaj        B.hons

# %%
res = pd.merge(df, df1, how='outer', on=['key', 'key1'])

res
# Out:
#   key key1    Name   Age    Address Qualification
# 0  K0   K0     Jai  27.0     Nagpur         Btech
# 1  K1   K1  Princi  24.0        NaN           NaN
# 2  K2   K0  Gaurav  22.0  Allahabad          Bcom
# 3  K3   K1    Anuj  32.0        NaN           NaN
# 4  K1   K0     NaN   NaN     Kanpur           B.A
# 5  K3   K0     NaN   NaN    Kannuaj        B.hons

# %%
res = pd.merge(df, df1, how='inner', on=['key', 'key1'])

res
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K2   K0  Gaurav   22  Allahabad          Bcom

# %%
import pandas as pd

# Define a dictionary containing employee data
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32]}

# Define a dictionary containing employee data
data2 = {'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'],
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons']}


df = pd.DataFrame(data1,index=['K0', 'K1', 'K2', 'K3'])
df1 = pd.DataFrame(data2, index=['K0', 'K2', 'K3', 'K4'])

# %%
res = df.join(df1)
res
# Out:
#       Name  Age    Address Qualification
# K0     Jai   27  Allahabad           MCA
# K1  Princi   24        NaN           NaN
# K2  Gaurav   22    Kannuaj           Phd
# K3    Anuj   32  Allahabad          Bcom

# %%
res1 = df.join(df1,how='outer')
res1
# Out:
#       Name   Age    Address Qualification
# K0     Jai  27.0  Allahabad           MCA
# K1  Princi  24.0        NaN           NaN
# K2  Gaurav  22.0    Kannuaj           Phd
# K3    Anuj  32.0  Allahabad          Bcom
# K4     NaN   NaN    Kannuaj        B.hons

# %%
res2 = df.join(df1,how='inner')
res2
# Out:
#       Name  Age    Address Qualification
# K0     Jai   27  Allahabad           MCA
# K2  Gaurav   22    Kannuaj           Phd
# K3    Anuj   32  Allahabad          Bcom

# %%
import pandas as pd
df1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    index=[0, 1, 2, 3],
)
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2 = pd.DataFrame(
    {
        "A": ["A4", "A5", "A6", "A7"],
        "B": ["B4", "B5", "B6", "B7"],
        "C": ["C4", "C5", "C6", "C7"],
        "D": ["D4", "D5", "D6", "D7"],
    },
    index=[4, 5, 6, 7],
)

# %%
df3 = pd.DataFrame(
    {
        "A": ["A8", "A9", "A10", "A11"],
        "B": ["B8", "B9", "B10", "B11"],
        "C": ["C8", "C9", "C10", "C11"],
        "D": ["D8", "D9", "D10", "D11"],
    },
    index=[8, 9, 10, 11],
)

# %%
frames =[df1,df2,df3]

# %%
result = pd.concat(frames)
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df4 = pd.DataFrame(
    {
        "B": ["B2", "B3", "B6", "B7"],
        "D": ["D2", "D3", "D6", "D7"],
        "F": ["F2", "F3", "F6", "F7"],
    },
    index=[2, 3, 6, 7]
)
df4
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
result = pd.concat([df1, df4], axis=1)
result
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
result = pd.concat([df1, df4], axis=0)
result
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 2  NaN  B2  NaN  D2   F2
# 3  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
result = pd.concat([df1, df4], axis=0,join="inner")
result
# Out:
#     B   D
# 0  B0  D0
# 1  B1  D1
# 2  B2  D2
# 3  B3  D3
# 2  B2  D2
# 3  B3  D3
# 6  B6  D6
# 7  B7  D7

# %%
result = pd.concat([df1, df4], axis=1,join="inner")
result
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3
