# %% [markdown]
# <a href="https://colab.research.google.com/github/labib1910024/Python_basic/blob/main/Matplotlb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l =[[420,380,390],[50,40,45]]
list2 = []
for j in range(0,3):
  list3 = []
  for i in range(0,len(l)):
      list3.append(l[i][j])
  list2.append(list3)

print(list2)
# Out:
# [[420, 50], [380, 40], [390, 45]]

# %%
l
# Out:
# [[420, 380, 390], [50, 40, 45]]

# %%
import matplotlib.pyplot as plt

# %%
x = [20,30,55,60,75]
y = [2,4,6,8,10]
plt.title('Relation')
plt.xlabel("x")
plt.ylabel("y")
plt.plot(y,x)
plt.show()

# %%
x = [20,30,55,60,75]
y = [2,4,6,8,10]
plt.title('Relation')
plt.xlabel("x")
plt.ylabel("y")
plt.plot(y,x,'r')
plt.show()

# %%
x = [20,30,55,60,75]
y = [2,4,6,8,10]
plt.title('Relation')
plt.xlabel("x")
plt.ylabel("y")
plt.plot(y,x,'-k')
plt.show()

# %%
x = [20,30,55,60,75]
y = [2,4,6,8,10]
plt.title('Relation')
plt.xlabel("x")
plt.ylabel("y")
plt.plot(y,x,'ro')
plt.show()

# %%
x = [20,30,55,60,75]
y = [2,4,6,8,10]
plt.title('Relation')
plt.xlabel("x")
plt.ylabel("y")
plt.plot(y,x,'--')
plt.show()

# %%
x = [20,30,55,60,75]
y = [2,4,6,8,10]
plt.title('Relation')
plt.xlabel("x")
plt.ylabel("y")
plt.plot(y,x,'^k:')
plt.show()

# %%
Vehicle = ['Car','Bus','Train']
No_Vehicle =[20,40,12]
plt.title('Cars and number')
plt.xlabel('Cars')
plt.ylabel('Number')
plt.bar(Vehicle,No_Vehicle)
plt.show()

# %%
Vehicle = ['Car','Bus','Train']
No_Vehicle =[20,40,12]
plt.title('Cars and number')
plt.xlabel('Cars')
plt.ylabel('Number')
plt.bar(Vehicle,No_Vehicle,color='g')
plt.show()

# %%
Vehicle = ['Car','Bus','Train']
No_Vehicle =[20,40,12]
plt.title('Cars and number')


plt.subplot(3,1,1)
plt.bar(Vehicle,No_Vehicle,color='g')

plt.subplot(3,1,2)
plt.plot(Vehicle,No_Vehicle,color='g')

plt.subplot(3,1,3)
plt.scatter(Vehicle,No_Vehicle,color='g')

plt.show()
# Out:
# <ipython-input-15-3afebd6a31f7>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,1,1)

# %%
Vehicle = ['Car','Bus','Train']
No_Vehicle =[20,40,12]
plt.title('Cars and number')


plt.subplot(1,3,1)
plt.bar(Vehicle,No_Vehicle,color='g')

plt.subplot(1,3,2)
plt.plot(Vehicle,No_Vehicle,color='g')

plt.subplot(1,3,3)
plt.scatter(Vehicle,No_Vehicle,color='g')

plt.show()
# Out:
# <ipython-input-16-52abe2969b35>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,3,1)

# %%
lab = ['Python', 'C++', 'Ruby', 'Java']
sizes = [215, 130, 245, 210]
clr = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
exp = (0.1, 0, 0, 0)


plt.pie(sizes, explode=exp, labels=lab, colors=clr,
autopct='%1.1f%%', shadow=True, startangle=140)


plt.show()

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_width',color='species')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns

x = [1, 2, 3, 4]
y = [5, 6, 7, 8]
sns.scatterplot(x=x, y=y)
plt.show()

# %%
Vehicle = ['Car', 'Bus', 'Train']
No_Vehicle = [20, 40, 12]
sns.barplot(x=Vehicle, y=No_Vehicle, color='g')


plt.xlabel('Vehicle Type')
plt.ylabel('Number of Vehicles')
plt.title('Number of Vehicles by Type')


plt.show()

# %%
# Box Plot
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


data = {
    'Category': ['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'],
    'Value': [10, 20, 15, 25, 30, 22, 15, 18, 14]
}


df = pd.DataFrame(data)


sns.boxplot(x='Category', y='Value', data=df)


plt.xlabel('Category')
plt.ylabel('Value')
plt.title('Box Plot of Values by Category')


plt.show()

# %%
# Count Plot
import seaborn as sns
import matplotlib.pyplot as plt


data = ['Car', 'Bus', 'Car', 'Train', 'Bus', 'Bus', 'Car', 'Car', 'Train', 'Car']
sns.countplot(x=data)


plt.xlabel('Vehicle Type')
plt.ylabel('Count')
plt.title('Count Plot of Vehicle Types')

plt.show()
