# %% [markdown]
# <a href="https://colab.research.google.com/github/labib1910024/Python_basic/blob/main/Matplotlb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l =[[420,380,390],[50,40,45]]
list2 = []
for j in range(0,3):
  list3 = []
  for i in range(0,len(l)):
      list3.append(l[i][j])
  list2.append(list3)

print(list2)
# Out:
# [[420, 50], [380, 40], [390, 45]]

# %%
l
# Out:
# [[420, 380, 390], [50, 40, 45]]

# %%
import matplotlib.pyplot as plt

# %%
x = [20,30,55,60,75]
y = [2,4,6,8,10]
plt.title('Relation')
plt.xlabel("x")
plt.ylabel("y")
plt.plot(y,x)
plt.show()

# %%
x = [20,30,55,60,75]
y = [2,4,6,8,10]
plt.title('Relation')
plt.xlabel("x")
plt.ylabel("y")
plt.plot(y,x,'r')
plt.show()

# %%
x = [20,30,55,60,75]
y = [2,4,6,8,10]
plt.title('Relation')
plt.xlabel("x")
plt.ylabel("y")
plt.plot(y,x,'-k')
plt.show()

# %%
x = [20,30,55,60,75]
y = [2,4,6,8,10]
plt.title('Relation')
plt.xlabel("x")
plt.ylabel("y")
plt.plot(y,x,'ro')
plt.show()

# %%
x = [20,30,55,60,75]
y = [2,4,6,8,10]
plt.title('Relation')
plt.xlabel("x")
plt.ylabel("y")
plt.plot(y,x,'--')
plt.show()

# %%
x = [20,30,55,60,75]
y = [2,4,6,8,10]
plt.title('Relation')
plt.xlabel("x")
plt.ylabel("y")
plt.plot(y,x,'^k:')
plt.show()

# %%
Vehicle = ['Car','Bus','Train']
No_Vehicle =[20,40,12]
plt.title('Cars and number')
plt.xlabel('Cars')
plt.ylabel('Number')
plt.bar(Vehicle,No_Vehicle)
plt.show()

# %%
Vehicle = ['Car','Bus','Train']
No_Vehicle =[20,40,12]
plt.title('Cars and number')
plt.xlabel('Cars')
plt.ylabel('Number')
plt.bar(Vehicle,No_Vehicle,color='g')
plt.show()

# %%
Vehicle = ['Car','Bus','Train']
No_Vehicle =[20,40,12]
plt.title('Cars and number')


plt.subplot(3,1,1)
plt.bar(Vehicle,No_Vehicle,color='g')

plt.subplot(3,1,2)
plt.plot(Vehicle,No_Vehicle,color='g')

plt.subplot(3,1,3)
plt.scatter(Vehicle,No_Vehicle,color='g')

plt.show()
# Out:
# <ipython-input-15-3afebd6a31f7>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,1,1)

# %%
Vehicle = ['Car','Bus','Train']
No_Vehicle =[20,40,12]
plt.title('Cars and number')


plt.subplot(1,3,1)
plt.bar(Vehicle,No_Vehicle,color='g')

plt.subplot(1,3,2)
plt.plot(Vehicle,No_Vehicle,color='g')

plt.subplot(1,3,3)
plt.scatter(Vehicle,No_Vehicle,color='g')

plt.show()
# Out:
# <ipython-input-16-52abe2969b35>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,3,1)
